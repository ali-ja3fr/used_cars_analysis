# %%
import pandas

# %%
import pandas as pd

# %%
pd.read_csv('data_cars.csv')
# Out:
#         Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0        BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1        BMW    1 Series  2011  premium unleaded (required)      300.0
# 2        BMW    1 Series  2011  premium unleaded (required)      300.0
# 3        BMW    1 Series  2011  premium unleaded (required)      230.0
# 4        BMW    1 Series  2011  premium unleaded (required)      230.0
# ...      ...         ...   ...                          ...        ...
# 4994  Nissan    Frontier  2016             regular unleaded      261.0
# 4995  Nissan    Frontier  2016             regular unleaded      261.0
# 4996  Nissan    Frontier  2016             regular unleaded      152.0
# 4997  Nissan    Frontier  2016             regular unleaded      152.0
# 4998  Nissan    Frontier  2017             regular unleaded      261.0
#
#       Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0                  6.0            MANUAL  rear wheel drive              2.0
# 1                  6.0            MANUAL  rear wheel drive              2.0
# 2                  6.0            MANUAL  rear wheel drive              2.0
# 3                  6.0            MANUAL  rear wheel drive              2.0
# 4                  6.0            MANUAL  rear wheel drive              2.0
# ...                ...               ...               ...              ...
# 4994               6.0         AUTOMATIC  rear wheel drive              4.0
# 4995               6.0         AUTOMATIC  four wheel drive              4.0
# 4996               4.0         AUTOMATIC  rear wheel drive              4.0
# 4997               4.0            MANUAL  rear wheel drive              4.0
# 4998               6.0         AUTOMATIC  rear wheel drive              4.0
#
#                             Market Category Vehicle Size        Vehicle Style  \
# 0     Factory Tuner,Luxury,High-Performance      Compact                Coupe
# 1                        Luxury,Performance      Compact          Convertible
# 2                   Luxury,High-Performance      Compact                Coupe
# 3                        Luxury,Performance      Compact                Coupe
# 4                                    Luxury      Compact          Convertible
# ...                                     ...          ...                  ...
# 4994                                    NaN      Compact      Crew Cab Pickup
# 4995                                    NaN      Compact      Crew Cab Pickup
# 4996                                    NaN      Compact  Extended Cab Pickup
# 4997                                    NaN      Compact  Extended Cab Pickup
# 4998                                    NaN      Compact      Crew Cab Pickup
#
#       highway MPG  city mpg  Popularity   MSRP   0
# 0              26        19        3916  46135 NaN
# 1              28        19        3916  40650 NaN
# 2              28        20        3916  36350 NaN
# 3              28        18        3916  29450 NaN
# 4              28        18        3916  34500 NaN
# ...           ...       ...         ...    ...  ..
# 4994           22        16        2009  31710 NaN
# 4995           21        15        2009  27960 NaN
# 4996           23        17        2009  20960 NaN
# 4997           23        19        2009  22180 NaN
# 4998           23        16        2009  25750 NaN
#
# [4999 rows x 17 columns]

# %%
cars_df = pd.read_csv('data_cars.csv')

# %%
cars_df.sample(10)
# Out:
#                Make                  Model  Year  \
# 1298            BMW        ActiveHybrid X6  2010
# 550            FIAT                    500  2015
# 2707  Mercedes-Benz              CLK-Class  2007
# 3615          Dodge                Durango  2015
# 2975      Chevrolet               Corvette  2015
# 2306            GMC                 Canyon  2016
# 2564          Honda                  Civic  2015
# 483          Toyota                4Runner  2014
# 965         Porsche                    911  2017
# 508             BMW  5 Series Gran Turismo  2015
#
#                     Engine Fuel Type  Engine HP  Engine Cylinders  \
# 1298     premium unleaded (required)      480.0               8.0
# 550   premium unleaded (recommended)      101.0               4.0
# 2707     premium unleaded (required)      268.0               6.0
# 3615                regular unleaded      290.0               6.0
# 2975  premium unleaded (recommended)      460.0               8.0
# 2306                regular unleaded      305.0               6.0
# 2564     premium unleaded (required)      205.0               4.0
# 483                 regular unleaded      270.0               6.0
# 965      premium unleaded (required)      370.0               6.0
# 508      premium unleaded (required)      445.0               8.0
#
#      Transmission Type      Driven_Wheels  Number of Doors  \
# 1298         AUTOMATIC    all wheel drive              4.0
# 550             MANUAL  front wheel drive              2.0
# 2707         AUTOMATIC   rear wheel drive              2.0
# 3615         AUTOMATIC    all wheel drive              4.0
# 2975            MANUAL   rear wheel drive              2.0
# 2306         AUTOMATIC   rear wheel drive              4.0
# 2564            MANUAL  front wheel drive              2.0
# 483          AUTOMATIC   four wheel drive              4.0
# 965             MANUAL    all wheel drive              2.0
# 508          AUTOMATIC   rear wheel drive              4.0
#
#                           Market Category Vehicle Size    Vehicle Style  \
# 1298  Crossover,Luxury,Performance,Hybrid      Midsize          4dr SUV
# 550                             Hatchback      Compact    2dr Hatchback
# 2707                   Luxury,Performance      Compact      Convertible
# 3615                            Crossover        Large          4dr SUV
# 2975                     High-Performance      Compact      Convertible
# 2306                               Diesel      Compact  Crew Cab Pickup
# 2564            Factory Tuner,Performance      Compact            Coupe
# 483                                   NaN      Midsize          4dr SUV
# 965               Luxury,High-Performance      Compact            Coupe
# 508          Hatchback,Luxury,Performance        Large    4dr Hatchback
#
#       highway MPG  city mpg  Popularity    MSRP   0
# 1298           19        17        3916   88900 NaN
# 550            40        31         819   17700 NaN
# 2707           25        17         617   54200 NaN
# 3615           24        17        1851   43595 NaN
# 2975           29        17        1385   73450 NaN
# 2306           26        18         549   30765 NaN
# 2564           31        22        2202   24590 NaN
# 483            22        17        2031   35725 NaN
# 965            28        19        1715  108600 NaN
# 508            25        16        3916   69100 NaN

# %%
cars_df.dtypes
# Out:
# Make                  object
# Model                 object
# Year                   int64
# Engine Fuel Type      object
# Engine HP            float64
# Engine Cylinders     float64
# Transmission Type     object
# Driven_Wheels         object
# Number of Doors      float64
# Market Category       object
# Vehicle Size          object
# Vehicle Style         object
# highway MPG            int64
# city mpg               int64
# Popularity             int64
# MSRP                   int64
# 0                    float64
# dtype: object

# %%
cars_df.drop(columns= ['0'], inplace=True)

# %%
print(cars_df['Transmission Type'].unique())
# Out:
# ['MANUAL' 'AUTOMATIC' 'AUTOMATED_MANUAL' 'DIRECT_DRIVE' 'UNKNOWN']

# %%
automatic_count = (cars_df['Transmission Type'] == 'AUTOMATIC').sum()
print("Number of cars with automatic transmission:", automatic_count)
# Out:
# Number of cars with automatic transmission: 3293

# %%
automatic_count = (cars_df['Transmission Type'] == 'MANUAL').sum()
print("Number of cars with MANUAL transmission:", automatic_count)
# Out:
# Number of cars with MANUAL transmission: 1440

# %%
automatic_count = (cars_df['Transmission Type'] == 'AUTOMATED_MANUAL').sum()
print("Number of cars with AUTOMATED_MANUAL transmission:", automatic_count)
# Out:
# Number of cars with AUTOMATED_MANUAL transmission: 244

# %%
automatic_count = (cars_df['Transmission Type'] == 'DIRECT_DRIVE').sum()
print("Number of cars with DIRECT_DRIVE transmission:", automatic_count)
# Out:
# Number of cars with DIRECT_DRIVE transmission: 17

# %%
automatic_count = (cars_df['Transmission Type'] == 'UNKNOWN').sum()
print("Number of cars with UNKNOWN transmission:", automatic_count)
# Out:
# Number of cars with UNKNOWN transmission: 5

# %%
print(cars_df['Make'].unique())
# Out:
# ['BMW' 'Audi' 'FIAT' 'Mercedes-Benz' 'Chrysler' 'Nissan' 'Volvo' 'Mazda'
#  'Mitsubishi' 'Ferrari' 'Alfa Romeo' 'Toyota' 'McLaren' 'Maybach'
#  'Pontiac' 'Porsche' 'Saab' 'GMC' 'Hyundai' 'Plymouth' 'Honda'
#  'Oldsmobile' 'Suzuki' 'Ford' 'Cadillac' 'Kia' 'Bentley' 'Chevrolet'
#  'Dodge' 'Lamborghini' 'Lincoln' 'Subaru' 'Volkswagen' 'Spyker' 'Buick'
#  'Acura' 'Rolls-Royce' 'Maserati' 'Lexus' 'Aston Martin' 'Land Rover'
#  'Lotus' 'Infiniti' 'Scion']

# %%
print(cars_df['Vehicle Style'].unique())
# Out:
# ['Coupe' 'Convertible' 'Sedan' 'Wagon' '4dr Hatchback' '2dr Hatchback'
#  '4dr SUV' 'Passenger Minivan' 'Cargo Minivan' 'Crew Cab Pickup'
#  'Regular Cab Pickup' 'Extended Cab Pickup' '2dr SUV' 'Cargo Van'
#  'Convertible SUV' 'Passenger Van']

# %%
print(cars_df['Vehicle Style'].value_counts())
# Out:
# Vehicle Style
# Sedan                  1402
# 4dr SUV                 768
# Coupe                   732
# Convertible             482
# Wagon                   279
# Crew Cab Pickup         273
# 2dr Hatchback           240
# Extended Cab Pickup     238
# 4dr Hatchback           237
# Regular Cab Pickup      132
# Passenger Minivan        58
# 2dr SUV                  49
# Passenger Van            44
# Cargo Van                43
# Cargo Minivan            21
# Convertible SUV           1
# Name: count, dtype: int64

# %%
cars_df['MSRP_formatted']= cars_df['MSRP'].apply(lambda x: "${:,.0f}".format(x))
cars_df
# Out:
#         Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0        BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1        BMW    1 Series  2011  premium unleaded (required)      300.0
# 2        BMW    1 Series  2011  premium unleaded (required)      300.0
# 3        BMW    1 Series  2011  premium unleaded (required)      230.0
# 4        BMW    1 Series  2011  premium unleaded (required)      230.0
# ...      ...         ...   ...                          ...        ...
# 4994  Nissan    Frontier  2016             regular unleaded      261.0
# 4995  Nissan    Frontier  2016             regular unleaded      261.0
# 4996  Nissan    Frontier  2016             regular unleaded      152.0
# 4997  Nissan    Frontier  2016             regular unleaded      152.0
# 4998  Nissan    Frontier  2017             regular unleaded      261.0
#
#       Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0                  6.0            MANUAL  rear wheel drive              2.0
# 1                  6.0            MANUAL  rear wheel drive              2.0
# 2                  6.0            MANUAL  rear wheel drive              2.0
# 3                  6.0            MANUAL  rear wheel drive              2.0
# 4                  6.0            MANUAL  rear wheel drive              2.0
# ...                ...               ...               ...              ...
# 4994               6.0         AUTOMATIC  rear wheel drive              4.0
# 4995               6.0         AUTOMATIC  four wheel drive              4.0
# 4996               4.0         AUTOMATIC  rear wheel drive              4.0
# 4997               4.0            MANUAL  rear wheel drive              4.0
# 4998               6.0         AUTOMATIC  rear wheel drive              4.0
#
#                             Market Category Vehicle Size        Vehicle Style  \
# 0     Factory Tuner,Luxury,High-Performance      Compact                Coupe
# 1                        Luxury,Performance      Compact          Convertible
# 2                   Luxury,High-Performance      Compact                Coupe
# 3                        Luxury,Performance      Compact                Coupe
# 4                                    Luxury      Compact          Convertible
# ...                                     ...          ...                  ...
# 4994                                    NaN      Compact      Crew Cab Pickup
# 4995                                    NaN      Compact      Crew Cab Pickup
# 4996                                    NaN      Compact  Extended Cab Pickup
# 4997                                    NaN      Compact  Extended Cab Pickup
# 4998                                    NaN      Compact      Crew Cab Pickup
#
#       highway MPG  city mpg  Popularity   MSRP   0  MSRP_numeric  \
# 0              26        19        3916  46135 NaN       46135.0
# 1              28        19        3916  40650 NaN       40650.0
# 2              28        20        3916  36350 NaN       36350.0
# 3              28        18        3916  29450 NaN       29450.0
# 4              28        18        3916  34500 NaN       34500.0
# ...           ...       ...         ...    ...  ..           ...
# 4994           22        16        2009  31710 NaN       31710.0
# 4995           21        15        2009  27960 NaN       27960.0
# 4996           23        17        2009  20960 NaN       20960.0
# 4997           23        19        2009  22180 NaN       22180.0
# 4998           23        16        2009  25750 NaN       25750.0
#
#      MSRP_formatted
# 0           $46,135
# 1           $40,650
# 2           $36,350
# 3           $29,450
# 4           $34,500
# ...             ...
# 4994        $31,710
# 4995        $27,960
# 4996        $20,960
# 4997        $22,180
# 4998        $25,750
#
# [4999 rows x 19 columns]

# %%
avg_popularity_sedan = cars_df[cars_df['Vehicle Style'] == 'Sedan']['Popularity'].mean()
print(f"Average Popularity for Sedans: {avg_popularity_sedan:.2f}")
# Out:
# Average Popularity for Sedans: 1699.48

# %%
avg_popularity_suv = cars_df[cars_df['Vehicle Style'].str.contains('suv', case=False, na=False)]['Popularity'].mean()
print(f"Average Popularity for SUVs: {avg_popularity_suv:.2f}")
# Out:
# Average Popularity for SUVs: 1833.92

# %%
avg_popularity_by_style = cars_df.groupby('Vehicle Style')['Popularity'].mean().sort_values(ascending=False)

print(avg_popularity_by_style)
# Out:
# Vehicle Style
# Cargo Van              4564.162791
# 2dr SUV                4298.428571
# Passenger Van          4006.454545
# Regular Cab Pickup     3247.250000
# Crew Cab Pickup        2814.084249
# Passenger Minivan      2749.500000
# Cargo Minivan          2672.142857
# Extended Cab Pickup    2490.785714
# 4dr Hatchback          2057.029536
# Wagon                  1828.168459
# Sedan                  1699.480029
# Coupe                  1692.163934
# 4dr SUV                1678.730469
# Convertible            1467.373444
# 2dr Hatchback          1298.875000
# Convertible SUV         258.000000
# Name: Popularity, dtype: float64

# %%
average_year = cars_df['Year'].mean()
print(f"Average Year of Cars: {average_year:.2f}")
# Out:
# Average Year of Cars: 2010.12

# %%
print(f"Average Year of Cars (Rounded): {round(average_year)}")
# Out:
# Average Year of Cars (Rounded): 2010

# %%
newer_cars = cars_df[cars_df['Year'] > 2015]

print(f"Number of cars from after 2015: {len(newer_cars)}")
newer_cars.sample(20)
# Out:
# Number of cars from after 2015: 1605
#                Make                  Model  Year  \
# 381           Mazda                      3  2016
# 404           Mazda                      3  2017
# 514             BMW  5 Series Gran Turismo  2017
# 2990      Chevrolet               Corvette  2016
# 4855         Subaru               Forester  2017
# 4766           Ford                   Flex  2017
# 1871     Volkswagen     Beetle Convertible  2016
# 1264          Honda                 Accord  2017
# 4878            Kia                  Forte  2017
# 1506       Cadillac              ATS Coupe  2016
# 2467          Dodge             Challenger  2017
# 503          Toyota                4Runner  2016
# 2090  Mercedes-Benz                C-Class  2017
# 158             BMW               3 Series  2017
# 2957         Toyota                Corolla  2017
# 4197           Ford                 Escape  2016
# 1631    Lamborghini              Aventador  2016
# 4876            Kia                  Forte  2016
# 2097           Ford           C-Max Hybrid  2016
# 1941     Volkswagen                 Beetle  2016
#
#                     Engine Fuel Type  Engine HP  Engine Cylinders  \
# 381                 regular unleaded      155.0               4.0
# 404                 regular unleaded      184.0               4.0
# 514      premium unleaded (required)      445.0               8.0
# 2990     premium unleaded (required)      650.0               8.0
# 4855                regular unleaded      170.0               4.0
# 4766                regular unleaded      287.0               6.0
# 1871  premium unleaded (recommended)      210.0               4.0
# 1264                regular unleaded      185.0               4.0
# 4878                regular unleaded      147.0               4.0
# 1506  premium unleaded (recommended)      272.0               4.0
# 2467  premium unleaded (recommended)      485.0               8.0
# 503                 regular unleaded      270.0               6.0
# 2090     premium unleaded (required)      241.0               4.0
# 158   premium unleaded (recommended)      248.0               4.0
# 2957                regular unleaded      132.0               4.0
# 4197  premium unleaded (recommended)      178.0               4.0
# 1631     premium unleaded (required)      700.0              12.0
# 4876                regular unleaded      201.0               4.0
# 2097                regular unleaded      188.0               4.0
# 1941  premium unleaded (recommended)      210.0               4.0
#
#      Transmission Type      Driven_Wheels  Number of Doors  \
# 381          AUTOMATIC  front wheel drive              4.0
# 404             MANUAL  front wheel drive              4.0
# 514          AUTOMATIC    all wheel drive              4.0
# 2990            MANUAL   rear wheel drive              2.0
# 4855         AUTOMATIC    all wheel drive              4.0
# 4766         AUTOMATIC    all wheel drive              4.0
# 1871  AUTOMATED_MANUAL  front wheel drive              2.0
# 1264            MANUAL  front wheel drive              2.0
# 4878         AUTOMATIC  front wheel drive              4.0
# 1506         AUTOMATIC   rear wheel drive              2.0
# 2467            MANUAL   rear wheel drive              2.0
# 503          AUTOMATIC   four wheel drive              4.0
# 2090         AUTOMATIC    all wheel drive              4.0
# 158          AUTOMATIC    all wheel drive              4.0
# 2957         AUTOMATIC  front wheel drive              4.0
# 4197         AUTOMATIC    all wheel drive              4.0
# 1631  AUTOMATED_MANUAL    all wheel drive              2.0
# 4876            MANUAL  front wheel drive              4.0
# 2097         AUTOMATIC  front wheel drive              4.0
# 1941  AUTOMATED_MANUAL  front wheel drive              2.0
#
#                      Market Category Vehicle Size  Vehicle Style  highway MPG  \
# 381                              NaN      Compact          Sedan           41
# 404            Hatchback,Performance      Compact  4dr Hatchback           33
# 514     Hatchback,Luxury,Performance        Large  4dr Hatchback           24
# 2990  Factory Tuner,High-Performance      Compact    Convertible           22
# 4855                       Crossover      Midsize        4dr SUV           32
# 4766           Crossover,Performance        Large          Wagon           22
# 1871                     Performance      Compact    Convertible           31
# 1264                             NaN      Midsize          Coupe           32
# 4878                             NaN      Compact          Sedan           38
# 1506              Luxury,Performance      Compact          Coupe           31
# 2467  Factory Tuner,High-Performance        Large          Coupe           23
# 503                              NaN      Midsize        4dr SUV           21
# 2090                          Luxury      Midsize          Sedan           31
# 158                           Luxury      Midsize          Sedan           33
# 2957                             NaN      Compact          Sedan           35
# 4197                       Crossover      Compact        4dr SUV           29
# 1631         Exotic,High-Performance      Midsize          Coupe           18
# 4876           Hatchback,Performance      Compact  4dr Hatchback           29
# 2097                          Hybrid      Compact          Wagon           37
# 1941           Hatchback,Performance      Compact  2dr Hatchback           31
#
#       city mpg  Popularity    MSRP MSRP_formatted
# 381         30         586   21095        $21,095
# 404         25         586   23895        $23,895
# 514         15        3916   72500        $72,500
# 2990        15        1385   83400        $83,400
# 4855        26         640   31295        $31,295
# 4766        16        5657   40180        $40,180
# 1871        23         873   36050        $36,050
# 1264        23        2202   26150        $26,150
# 4878        29        1720   17500        $17,500
# 1506        22        1624   45445        $45,445
# 2467        14        1851   37995        $37,995
# 503         17        2031   36915        $36,915
# 2090        24         617   41500        $41,500
# 158         23        3916   40750        $40,750
# 2957        28        2031   20445        $20,445
# 4197        22        5657   27540        $27,540
# 1631        11        1158  399500       $399,500
# 4876        21        1720   20990        $20,990
# 2097        42        5657   24170        $24,170
# 1941        24         873   32550        $32,550

# %%
# Ensure MSRP is numeric (if not already)
cars_df['MSRP_numeric'] = cars_df['MSRP_formatted'].replace('[\$,]', '', regex=True).astype(float)

# Filter for the 3 specific vehicle styles
target_styles = ['Cargo Van', '2dr SUV', 'Passenger Van']
filtered_df = cars_df[cars_df['Vehicle Style'].isin(target_styles)]

# Calculate the average MSRP (numeric)
avg_msrp_raw = filtered_df.groupby('Vehicle Style')['MSRP_numeric'].mean()

# Display the result
print(avg_msrp_raw)
# Out:
# Vehicle Style
# 2dr SUV          17118.918367
# Cargo Van        15000.906977
# Passenger Van    27572.454545
# Name: MSRP_numeric, dtype: float64

# %%
# Filter only Cargo Vans
cargo_vans = cars_df[cars_df['Vehicle Style'] == 'Passenger Van']

# Group by Make and count
cargo_van_counts = cargo_vans['Make'].value_counts()

# Display results
print(cargo_van_counts)
# Out:
# Make
# Ford         27
# Chevrolet    17
# Name: count, dtype: int64
